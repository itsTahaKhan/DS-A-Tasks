# %% [markdown]
# <a href="https://colab.research.google.com/github/Celestial00/DS-A/blob/main/20sw050(lab12).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "/content/sample_data/schoolw.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning.
# Tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness
# of all content. While using W3Schools, you agree to have read and accepted our terms of use,
# cookie and privacy policy.
# Copyright 1999-2023 by Refsnes Data. All Rights Reserved.
# W3Schools is Powered by W3.CSS.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.w3schools.com/java/java_intro.asp")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Introduction to Java</title>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="Keywords" content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website">
# <meta name="Description" content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more.">
# <meta property="og:image" content="https://www.w3schools.com/images/w3schools_logo_436_2.png">
# <meta property="og:image:type" content="image/png">
# <meta property="og:image:width" content="436">
# ...

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Introduction to Java
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KTCFC3S');
#
# var subjectFolder = location.pathname;
# subjectFolder = subjectFolder.replace("/", "");
# if (subjectFolder.startsWith("python/") == true ) {
#   if (subjectFolder.includes("/numpy/") == true ) {
#     subjectFolder = "numpy/"
#   } else if (subjectFolder.includes("/pandas/") == true ) {
#       subjectFolder = "pandas/"
#   } else if (subjectFolder.includes("/scipy/") == true ) {
#       subjectFolder = "scipy/"
#   }
# }
# subjectFolder = subjectFolder.substr(0, subjectFolder.indexOf("/"));
#
#
#
#
#
# var k42 = false;
# // GPT slots
# ...

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Introduction to Java
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KTCFC3S');
#
# var subjectFolder = location.pathname;
# subjectFolder = subjectFolder.replace("/", "");
# if (subjectFolder.startsWith("python/") == true ) {
#   if (subjectFolder.includes("/numpy/") == true ) {
#     subjectFolder = "numpy/"
#   } else if (subjectFolder.includes("/pandas/") == true ) {
#       subjectFolder = "pandas/"
#   } else if (subjectFolder.includes("/scipy/") == true ) {
#       subjectFolder = "scipy/"
#   }
# }
# subjectFolder = subjectFolder.substr(0, subjectFolder.indexOf("/"));
#
#
#
#
#
# var k42 = false;
# // GPT slots
# ...

# %%
# Find all articles
summaries = soup.find_all("div", class_="footertext")
summaries[0]
# Out:
# <div class="footertext">
# W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning.<br class="footer-hide-special"/>
# Tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness<br class="footer-hide-special"/>
# of all content. While using W3Schools, you agree to have read and accepted our <a class="ga-bottom" href="/about/about_copyright.asp">terms of use</a>,
# <a class="ga-bottom" href="/about/about_privacy.asp">cookie and privacy policy</a>.<br/><br/>
# <a class="ga-bottom" href="/about/about_copyright.asp">Copyright 1999-2023</a> by Refsnes Data. All Rights Reserved.
# <a class="ga-bottom" href="//www.w3schools.com/w3css/default.asp">W3Schools is Powered by W3.CSS</a>.<br/><br/>
# </div>

# %%
# Extract title
summaries[0].find("a", class_="ga-bottom").get_text().strip()
# Out:
# 'terms of use'

# %%
summaries[0].get_text().strip()
# Out:
# 'W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning.\nTutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness\nof all content. While using W3Schools, you agree to have read and accepted our terms of use, \ncookie and privacy policy.\nCopyright 1999-2023 by Refsnes Data. All Rights Reserved.\nW3Schools is Powered by W3.CSS.'

# %%
# Find all articles, extract titles
articles = []
summaries = soup.find_all("tr", class_="athing")
for summary in summaries:
    title = summary.find("a", class_="storylink").get_text().strip()
    articles.append((title))

print(len(articles), "Article summaries found. Sample:")
print(articles[0])

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning. Tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness of all content. While using W3Schools, you agree to have read and accepted our terms of use,  cookie and privacy policy. Copyright 1999-2023 by Refsnes Data. All Rights Reserved. W3Schools is Powered by W3.CSS."
print(text)
# Out:
# W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning. Tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness of all content. While using W3Schools, you agree to have read and accepted our terms of use,  cookie and privacy policy. Copyright 1999-2023 by Refsnes Data. All Rights Reserved. W3Schools is Powered by W3.CSS.

# %%
# Convert to lowercase
text = text.lower()
print(text)
# Out:
# w3schools is optimized for learning and training. examples might be simplified to improve reading and learning. tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness of all content. while using w3schools, you agree to have read and accepted our terms of use,  cookie and privacy policy. copyright 1999-2023 by refsnes data. all rights reserved. w3schools is powered by w3.css.

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text)
print(text)
# Out:
# w3schools is optimized for learning and training  examples might be simplified to improve reading and learning  tutorials  references  and examples are constantly reviewed to avoid errors  but we cannot warrant full correctness of all content  while using w3schools  you agree to have read and accepted our terms of use   cookie and privacy policy  copyright 1999 2023 by refsnes data  all rights reserved  w3schools is powered by w3 css

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['w3schools', 'is', 'optimized', 'for', 'learning', 'and', 'training', 'examples', 'might', 'be', 'simplified', 'to', 'improve', 'reading', 'and', 'learning', 'tutorials', 'references', 'and', 'examples', 'are', 'constantly', 'reviewed', 'to', 'avoid', 'errors', 'but', 'we', 'cannot', 'warrant', 'full', 'correctness', 'of', 'all', 'content', 'while', 'using', 'w3schools', 'you', 'agree', 'to', 'have', 'read', 'and', 'accepted', 'our', 'terms', 'of', 'use', 'cookie', 'and', 'privacy', 'policy', 'copyright', '1999', '2023', 'by', 'refsnes', 'data', 'all', 'rights', 'reserved', 'w3schools', 'is', 'powered', 'by', 'w3', 'css']

# %%
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['w3schools', 'is', 'optimized', 'for', 'learning', 'and', 'training', 'examples', 'might', 'be', 'simplified', 'to', 'improve', 'reading', 'and', 'learning', 'tutorials', 'references', 'and', 'examples', 'are', 'constantly', 'reviewed', 'to', 'avoid', 'errors', 'but', 'we', 'cannot', 'warrant', 'full', 'correctness', 'of', 'all', 'content', 'while', 'using', 'w3schools', 'you', 'agree', 'to', 'have', 'read', 'and', 'accepted', 'our', 'terms', 'of', 'use', 'cookie', 'and', 'privacy', 'policy', 'copyright', '1999', '2023', 'by', 'refsnes', 'data', 'all', 'rights', 'reserved', 'w3schools', 'is', 'powered', 'by', 'w3', 'css']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Reset text
text = "W3Schools is optimized for learning and training. Examples might be simplified to improve reading and learning. Tutorials, references, and examples are constantly reviewed to avoid errors, but we cannot warrant full correctness of all content. While using W3Schools, you agree to have read and accepted our terms of use,  cookie and privacy policy. Copyright 1999-2023 by Refsnes Data. All Rights Reserved. W3Schools is Powered by W3.CSS"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['w3schools', 'is', 'optimized', 'for', 'learning', 'and', 'training', 'examples', 'might', 'be', 'simplified', 'to', 'improve', 'reading', 'and', 'learning', 'tutorials', 'references', 'and', 'examples', 'are', 'constantly', 'reviewed', 'to', 'avoid', 'errors', 'but', 'we', 'cannot', 'warrant', 'full', 'correctness', 'of', 'all', 'content', 'while', 'using', 'w3schools', 'you', 'agree', 'to', 'have', 'read', 'and', 'accepted', 'our', 'terms', 'of', 'use', 'cookie', 'and', 'privacy', 'policy', 'copyright', '1999', '2023', 'by', 'refsnes', 'data', 'all', 'rights', 'reserved', 'w3schools', 'is', 'powered', 'by', 'w3', 'css']

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# List stop words
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['w3schools', 'optimized', 'learning', 'training', 'examples', 'might', 'simplified', 'improve', 'reading', 'learning', 'tutorials', 'references', 'examples', 'constantly', 'reviewed', 'avoid', 'errors', 'cannot', 'warrant', 'full', 'correctness', 'content', 'using', 'w3schools', 'agree', 'read', 'accepted', 'terms', 'use', 'cookie', 'privacy', 'policy', 'copyright', '1999', '2023', 'refsnes', 'data', 'rights', 'reserved', 'w3schools', 'powered', 'w3', 'css']

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk
nltk.download('punkt')
# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("w3schools is optimized for learning and training  examples might be simplified to improve reading and learning  tutorials  references  and examples are constantly reviewed to avoid errors  but we cannot warrant full correctness of all content  while using w3schools  you agree to have read and accepted our terms of use   cookie and privacy policy  copyright 1999 2023 by refsnes data  all rights reserved  w3schools is powered by w3 css")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-c937ab73b4a1> in <cell line: 18>()
#      16 # Parse a sentence
#      17 sentence = word_tokenize("w3schools is optimized for learning and training  examples might be simplified to improve reading and learning  tutorials  references  and examples are constantly reviewed to avoid errors  but we cannot warrant full correctness of all content  while using w3schools  you agree to have read and accepted our terms of use   cookie and privacy policy  copyright 1999 2023 by refsnes data  all rights reserved  w3schools is powered by w3 css")
# ---> 18 for tree in parser.parse(sentence):
#      19     print(tree)
#
# ...

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['w3school', 'optim', 'learn', 'train', 'exampl', 'might', 'simplifi', 'improv', 'read', 'learn', 'tutori', 'refer', 'exampl', 'constantli', 'review', 'avoid', 'error', 'cannot', 'warrant', 'full', 'correct', 'content', 'use', 'w3school', 'agre', 'read', 'accept', 'term', 'use', 'cooki', 'privaci', 'polici', 'copyright', '1999', '2023', 'refsn', 'data', 'right', 'reserv', 'w3school', 'power', 'w3', 'css']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer
import nltk
nltk.download('wordnet')
words = ['w3school', 'optim', 'learn', 'train', 'exampl', 'might', 'simplifi', 'improv', 'read', 'learn', 'tutori', 'refer', 'exampl', 'constantli', 'review', 'avoid', 'error', 'cannot', 'warrant', 'full', 'correct', 'content', 'use', 'w3school', 'agre', 'read', 'accept', 'term', 'use', 'cooki', 'privaci', 'polici', 'copyright', '1999', '2023', 'refsn', 'data', 'right', 'reserv', 'w3school', 'power', 'w3', 'css']
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]

print(lemmed)
# Out:
# ['w3school', 'optim', 'learn', 'train', 'exampl', 'might', 'simplifi', 'improv', 'read', 'learn', 'tutori', 'refer', 'exampl', 'constantli', 'review', 'avoid', 'error', 'cannot', 'warrant', 'full', 'correct', 'content', 'use', 'w3school', 'agre', 'read', 'accept', 'term', 'use', 'cooki', 'privaci', 'polici', 'copyright', '1999', '2023', 'refsn', 'data', 'right', 'reserv', 'w3school', 'power', 'w3', 'cs']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['w3school', 'optim', 'learn', 'train', 'exampl', 'might', 'simplifi', 'improv', 'read', 'learn', 'tutori', 'refer', 'exampl', 'constantli', 'review', 'avoid', 'error', 'cannot', 'warrant', 'full', 'correct', 'content', 'use', 'w3school', 'agre', 'read', 'accept', 'term', 'use', 'cooki', 'privaci', 'polici', 'copyright', '1999', '2023', 'refsn', 'data', 'right', 'reserv', 'w3school', 'power', 'w3', 'cs']
